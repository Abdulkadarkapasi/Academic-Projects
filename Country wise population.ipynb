# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statistics as st

# %%
data = pd.read_csv('D:/Dataset/population_by_country_2020.csv')

# %%
data.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
data.tail()
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 230              Montserrat               4991        0.06 %           3
# 231        Falkland Islands               3458        3.05 %         103
# 232                    Niue               1624        0.68 %          11
# 233                 Tokelau               1354        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 230               50              100             NaN       N.A.     N.A.
# 231                0            12170             NaN       N.A.     N.A.
# 232                6              260             NaN       N.A.     N.A.
# 233              136               10             NaN       N.A.     N.A.
# 234             2003                0             NaN       N.A.     N.A.
#
#     Urban Pop % World Share
# 230        10 %      0.00 %
# ...

# %%
data.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
data.shape
# Out:
# (235, 11)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Country (or dependency)'].values
# Out:
# array(['China', 'India', 'United States', 'Indonesia', 'Pakistan',
#        'Brazil', 'Nigeria', 'Bangladesh', 'Russia', 'Mexico', 'Japan',
#        'Ethiopia', 'Philippines', 'Egypt', 'Vietnam', 'DR Congo',
#        'Turkey', 'Iran', 'Germany', 'Thailand', 'United Kingdom',
#        'France', 'Italy', 'Tanzania', 'South Africa', 'Myanmar', 'Kenya',
#        'South Korea', 'Colombia', 'Spain', 'Uganda', 'Argentina',
#        'Algeria', 'Sudan', 'Ukraine', 'Iraq', 'Afghanistan', 'Poland',
#        'Canada', 'Morocco', 'Saudi Arabia', 'Uzbekistan', 'Peru',
#        'Angola', 'Malaysia', 'Mozambique', 'Ghana', 'Yemen', 'Nepal',
#        'Venezuela', 'Madagascar', 'Cameroon', "Côte d'Ivoire",
#        'North Korea', 'Australia', 'Niger', 'Taiwan', 'Sri Lanka',
#        'Burkina Faso', 'Mali', 'Romania', 'Malawi', 'Chile', 'Kazakhstan',
#        'Zambia', 'Guatemala', 'Ecuador', 'Syria', 'Netherlands',
#        'Senegal', 'Cambodia', 'Chad', 'Somalia', 'Zimbabwe', 'Guinea',
# ...

# %%
data['Country (or dependency)'].drop_duplicates()
# Out:
# 0                 China
# 1                 India
# 2         United States
# 3             Indonesia
# 4              Pakistan
#              ...
# 230          Montserrat
# 231    Falkland Islands
# 232                Niue
# 233             Tokelau
# 234            Holy See
# Name: Country (or dependency), Length: 235, dtype: object

# %%
data['Country (or dependency)'].dropna()
# Out:
# 0                 China
# 1                 India
# 2         United States
# 3             Indonesia
# 4              Pakistan
#              ...
# 230          Montserrat
# 231    Falkland Islands
# 232                Niue
# 233             Tokelau
# 234            Holy See
# Name: Country (or dependency), Length: 235, dtype: object

# %%
data['Country (or dependency)'].rename('Country')
# Out:
# 0                 China
# 1                 India
# 2         United States
# 3             Indonesia
# 4              Pakistan
#              ...
# 230          Montserrat
# 231    Falkland Islands
# 232                Niue
# 233             Tokelau
# 234            Holy See
# Name: Country, Length: 235, dtype: object

# %%
data.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
data.rename(columns={"Country (or dependency)":"Country"}, inplace= True)

# %%
data.dtypes
# Out:
# Country               object
# Population (2020)      int64
# Yearly Change         object
# Net Change             int64
# Density (P/Km²)        int64
# Land Area (Km²)        int64
# Migrants (net)       float64
# Fert. Rate            object
# Med. Age              object
# Urban Pop %           object
# World Share           object
# dtype: object

# %%
data['Land Area (Km²)'].aggregate(np.mean)
# Out:
# 553591.8425531915

# %%
data.head()
# Out:
#          Country  Population (2020) Yearly Change  Net Change  \
# 0          China         1438207241        0.39 %     5540090
# 1          India         1377233523        0.99 %    13586631
# 2  United States          330610570        0.59 %     1937734
# 3      Indonesia          272931713        1.07 %     2898047
# 4       Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# 2        83 %      4.25 %
# 3        56 %      3.51 %
# ...

# %%
data['Country'].sort_index(ascending=False)
# Out:
# 234            Holy See
# 233             Tokelau
# 232                Niue
# 231    Falkland Islands
# 230          Montserrat
#              ...
# 4              Pakistan
# 3             Indonesia
# 2         United States
# 1                 India
# 0                 China
# Name: Country, Length: 235, dtype: object

# %%
data.columns
# Out:
# Index(['Country', 'Population (2020)', 'Yearly Change', 'Net Change',
#        'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)', 'Fert. Rate',
#        'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
data_india = data.query("Country == 'India'")

# %%
data_india
# Out:
#   Country  Population (2020) Yearly Change  Net Change  Density (P/Km²)  \
# 1   India         1377233523        0.99 %    13586631              464
#
#    Land Area (Km²)  Migrants (net) Fert. Rate Med. Age Urban Pop % World Share
# 1          2973190       -532687.0        2.2       28        35 %     17.70 %

# %%
# Gives the output from index 1 to 10 (11 excludes)
data.iloc[1:11]
# Out:
#           Country  Population (2020) Yearly Change  Net Change  \
# 1           India         1377233523        0.99 %    13586631
# 2   United States          330610570        0.59 %     1937734
# 3       Indonesia          272931713        1.07 %     2898047
# 4        Pakistan          219992900        2.00 %     4327022
# 5          Brazil          212253150        0.72 %     1509890
# 6         Nigeria          205052107        2.58 %     5175990
# 7      Bangladesh          164354176        1.01 %     1643222
# 8          Russia          145922010        0.04 %       62206
# 9          Mexico          128655589        1.06 %     1357224
# 10          Japan          126552765       -0.30 %     -383840
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 1               464          2973190       -532687.0        2.2       28
# 2                36          9147420        954806.0        1.8       38
# ...

# %%
data.loc[: :3]
# Out:
#               Country  Population (2020) Yearly Change  Net Change  \
# 0               China         1438207241        0.39 %     5540090
# 3           Indonesia          272931713        1.07 %     2898047
# 6             Nigeria          205052107        2.58 %     5175990
# 9              Mexico          128655589        1.06 %     1357224
# 12        Philippines          109280343        1.35 %     1464463
# ..                ...                ...           ...         ...
# 222      Cook Islands              17561        0.09 %          16
# 225   Wallis & Futuna              11276       -1.69 %        -193
# 228      Saint Helena               6073        0.30 %          18
# 231  Falkland Islands               3458        3.05 %         103
# 234          Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                153          9388211       -348399.0        1.7       38
# ...

# %%
# data.ioc[]

# %%
data.sort_values(by = ['Country'])
# Out:
#              Country  Population (2020) Yearly Change  Net Change  \
# 36       Afghanistan           38742911        2.33 %      886592
# 139          Albania            2878420       -0.11 %       -3120
# 32           Algeria           43685618        1.85 %      797990
# 209   American Samoa              55215       -0.22 %        -121
# 202          Andorra              77240        0.16 %         123
# ..               ...                ...           ...         ...
# 225  Wallis & Futuna              11276       -1.69 %        -193
# 169   Western Sahara             594215        2.55 %       14876
# 47             Yemen           29687214        2.28 %      664042
# 64            Zambia           18273379        2.93 %      522925
# 73          Zimbabwe           14818157        1.48 %      217456
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 36                60           652860        -62920.0        4.6       18
# ...

# %%
data.dtypes
# Out:
# Country               object
# Population (2020)      int64
# Yearly Change         object
# Net Change             int64
# Density (P/Km²)        int64
# Land Area (Km²)        int64
# Migrants (net)       float64
# Fert. Rate            object
# Med. Age              object
# Urban Pop %           object
# World Share           object
# dtype: object

# %%
data.isna()
# Out:
#      Country  Population (2020)  Yearly Change  Net Change  Density (P/Km²)  \
# 0      False              False          False       False            False
# 1      False              False          False       False            False
# 2      False              False          False       False            False
# 3      False              False          False       False            False
# 4      False              False          False       False            False
# ..       ...                ...            ...         ...              ...
# 230    False              False          False       False            False
# 231    False              False          False       False            False
# 232    False              False          False       False            False
# 233    False              False          False       False            False
# 234    False              False          False       False            False
#
# ...

# %%
data.isna().sum()
# Out:
# Country               0
# Population (2020)     0
# Yearly Change         0
# Net Change            0
# Density (P/Km²)       0
# Land Area (Km²)       0
# Migrants (net)       34
# Fert. Rate            0
# Med. Age              0
# Urban Pop %           0
# World Share           0
# dtype: int64

# %%
# Replacing with missing values
data['Migrants (net)'].fillna(data['Migrants (net)'].mean(), inplace = True)

# %%
data.isna().sum()
# Out:
# Country              0
# Population (2020)    0
# Yearly Change        0
# Net Change           0
# Density (P/Km²)      0
# Land Area (Km²)      0
# Migrants (net)       0
# Fert. Rate           0
# Med. Age             0
# Urban Pop %          0
# World Share          0
# dtype: int64

# %%
data.describe()
# Out:
#        Population (2020)    Net Change  Density (P/Km²)  Land Area (Km²)  \
# count       2.350000e+02  2.350000e+02       235.000000     2.350000e+02
# mean        3.309773e+07  3.460878e+05       475.770213     5.535918e+05
# std         1.349417e+08  1.128260e+06      2331.285935     1.687796e+06
# min         8.010000e+02 -3.838400e+05         0.000000     0.000000e+00
# 25%         3.981150e+05  4.240000e+02        37.000000     2.545000e+03
# 50%         5.459116e+06  3.917000e+04        95.000000     7.724000e+04
# 75%         2.045283e+07  2.496600e+05       239.500000     4.038200e+05
# max         1.438207e+09  1.358663e+07     26337.000000     1.637687e+07
#
#        Migrants (net)
# count      235.000000
# mean         6.283582
# std     113983.390360
# min    -653249.000000
# 25%      -8608.000000
# 50%          0.000000
# 75%       4900.000000
# max     954806.000000

# %%
data.keys()
# Out:
# Index(['Country', 'Population (2020)', 'Yearly Change', 'Net Change',
#        'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)', 'Fert. Rate',
#        'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
data.values
# Out:
# array([['China', 1438207241, '0.39 %', ..., '38', '61 %', '18.47 %'],
#        ['India', 1377233523, '0.99 %', ..., '28', '35 %', '17.70 %'],
#        ['United States', 330610570, '0.59 %', ..., '38', '83 %',
#         '4.25 %'],
#        ...,
#        ['Niue', 1624, '0.68 %', ..., 'N.A.', '46 %', '0.00 %'],
#        ['Tokelau', 1354, '1.27 %', ..., 'N.A.', '0 %', '0.00 %'],
#        ['Holy See', 801, '0.25 %', ..., 'N.A.', 'N.A.', '0.00 %']],
#       dtype=object)

# %%
data.value_counts()
# Out:
# Country           Population (2020)  Yearly Change  Net Change  Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  Urban Pop %  World Share
# Afghanistan       38742911           2.33 %         886592      60               652860           -62920.000000   4.6         18        25 %         0.50 %         1
# Papua New Guinea  8911530            1.95 %         170915      20               452860           -800.000000     3.6         22        13 %         0.11 %         1
# Nicaragua         6608366            1.21 %         79052       55               120340           -21272.000000   2.4         26        57 %         0.08 %         1
# Niger             24014064           3.84 %         895929      19               1266700           4000.000000    7.0         15        17 %         0.31 %         1
# ...

# %%
data.dropna()
# Out:
#               Country  Population (2020) Yearly Change  Net Change  \
# 0               China         1438207241        0.39 %     5540090
# 1               India         1377233523        0.99 %    13586631
# 2       United States          330610570        0.59 %     1937734
# 3           Indonesia          272931713        1.07 %     2898047
# 4            Pakistan          219992900        2.00 %     4327022
# ..                ...                ...           ...         ...
# 230        Montserrat               4991        0.06 %           3
# 231  Falkland Islands               3458        3.05 %         103
# 232              Niue               1624        0.68 %          11
# 233           Tokelau               1354        1.27 %          17
# 234          Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                153          9388211  -348399.000000        1.7       38
# ...

# %% [markdown]
# **Univariate Analysis**

# %%
data.select_dtypes(include= 'int64')
# Out:
#      Population (2020)  Net Change  Density (P/Km²)  Land Area (Km²)
# 0           1438207241     5540090              153          9388211
# 1           1377233523    13586631              464          2973190
# 2            330610570     1937734               36          9147420
# 3            272931713     2898047              151          1811570
# 4            219992900     4327022              287           770880
# ..                 ...         ...              ...              ...
# 230               4991           3               50              100
# 231               3458         103                0            12170
# 232               1624          11                6              260
# 233               1354          17              136               10
# 234                801           2             2003                0
#
# [235 rows x 4 columns]

# %%
data.plot()
# Out:
# <Axes: >

# %%
data['Population (2020)'].plot(kind = 'kde', title= 'Population variable chart')
# Out:
# <Axes: title={'center': 'Population variable chart'}, ylabel='Density'>

# %%
data['Density (P/Km²)'].plot(kind= 'area', title= 'Density (p/km^2) variable chart')
# Out:
# <Axes: title={'center': 'Density (p/km^2) variable chart'}>

# %%
data['Net Change'].plot(kind = 'density', title = 'Net Change variable chart')
# Out:
# <Axes: title={'center': 'Net Change variable chart'}, ylabel='Density'>

# %%
data['Land Area (Km²)'].plot(kind = 'line', title= 'Land Area variable chart')
# Out:
# <Axes: title={'center': 'Land Area variable chart'}>

# %% [markdown]
# **Bi-Variate Analysis**

# %%
plt.figure(figsize = (10, 4))
# plt.rcParams.update({'font.size':12})
plt.bar(x = data['Country'].head(), height = data['Population (2020)'].head())
plt.xlabel('Country')
plt.ylabel('Population by 2020')
plt.title('Population by Country')
# Out:
# Text(0.5, 1.0, 'Population by Country')

# %%
plt.figure(figsize = (10, 4))
# plt.rcParams.update({'font.size':12})
plt.bar(x = data['Country'].head(), height = data['Density (P/Km²)'].head())
plt.xlabel('country')
plt.ylabel('Density (P/Km²)')
plt.title('Density (P/Km²) by Country')
# Out:
# Text(0.5, 1.0, 'Density (P/Km²) by Country')

# %%
plt.plot([1,2,3,5], [4,8,12,16], 'ro')
plt.axis([0, 6, 0, 20])
# Out:
# (0.0, 6.0, 0.0, 20.0)

# %%
def koch_snowflake(order, scale=10):
    """
    Return two lists x, y of point coordinates of the Koch snowflake.

    Parameters
    ----------
    order : int
        The recursion depth.
    scale : float
        The extent of the snowflake (edge length of the base triangle).
    """
    def _koch_snowflake_complex(order):
        if order == 0:
            # initial triangle
            angles = np.array([0, 120, 240]) + 90
            return scale / np.sqrt(3) * np.exp(np.deg2rad(angles) * 1j)
        else:
            ZR = 0.5 - 0.5j * np.sqrt(3) / 3

            p1 = _koch_snowflake_complex(order - 1)  # start points
            p2 = np.roll(p1, shift=-1)  # end points
            dp = p2 - p1  # connection vectors

            new_points = np.empty(len(p1) * 4, dtype=np.complex128)
            new_points[::4] = p1
            new_points[1::4] = p1 + dp / 3
            new_points[2::4] = p1 + dp * ZR
            new_points[3::4] = p1 + dp / 3 * 2
            return new_points

    points = _koch_snowflake_complex(order)
    x, y = points.real, points.imag
    return x, y

x, y = koch_snowflake(order = 5)
plt.figure(figsize= (8,8))
plt.axis('equal')
plt.fill(x, y)

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

# %%
plt.figure(figsize = (20, 5))
plt.subplot(131)
plt.bar(data['Country'].head(), height= data['Population (2020)'].head())
plt.subplot(132)
plt.scatter(data['Country'].head(), y = data['Population (2020)'].head())
plt.subplot(133)
plt.plot(data['Country'].head(), data['Population (2020)'].head())

# %%
ax = plt.subplot()

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()
